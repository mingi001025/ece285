# %% [markdown]
# # ECE 285 Assignment 1: Classification using Neural Network
#
# Now that you have developed and tested your model on the toy dataset set. It's time to get down and get dirty with a standard dataset such as cifar10. At this point, you will be using the provided training data to tune the hyper-parameters of your network such that it works with cifar10 for the task of multi-class classification.
#
# Important: Recall that now we have non-linear decision boundaries, thus we do not need to do one vs all classification. We learn a single non-linear decision boundary instead. Our non-linear boundaries (thanks to relu non-linearity) will take care of differentiating between all the classes
#
# TO SUBMIT: PDF of this notebook with all the required outputs and answers.

# %%
# Prepare Packages
import numpy as np
import matplotlib.pyplot as plt

from ece285.utils.data_processing import get_cifar10_data
from ece285.utils.evaluation import get_classification_accuracy


# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # set default size of plots

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Use a subset of CIFAR10 for the assignment
dataset = get_cifar10_data(
    subset_train=5000,
    subset_val=250,
    subset_test=500,
)

print(dataset.keys())
print("Training Set Data  Shape: ", dataset["x_train"].shape)
print("Training Set Label Shape: ", dataset["y_train"].shape)
print("Validation Set Data  Shape: ", dataset["x_val"].shape)
print("Validation Set Label Shape: ", dataset["y_val"].shape)
print("Test Set Data  Shape: ", dataset["x_test"].shape)
print("Test Set Label Shape: ", dataset["y_test"].shape)
# Out:
# dict_keys(['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test'])
# Training Set Data  Shape:  (5000, 3072)
# Training Set Label Shape:  (5000,)
# Validation Set Data  Shape:  (250, 3072)
# Validation Set Label Shape:  (250,)
# Test Set Data  Shape:  (500, 3072)
# Test Set Label Shape:  (500,)

# %%
x_train = dataset["x_train"]
y_train = dataset["y_train"]
x_val = dataset["x_val"]
y_val = dataset["y_val"]
x_test = dataset["x_test"]
y_test = dataset["y_test"]

# %%
# Import more utilies and the layers you have implemented
from ece285.layers.sequential import Sequential
from ece285.layers.linear import Linear
from ece285.layers.relu import ReLU
from ece285.layers.softmax import Softmax
from ece285.layers.loss_func import CrossEntropyLoss
from ece285.utils.optimizer import SGD
from ece285.utils.dataset import DataLoader
from ece285.utils.trainer import Trainer

# %% [markdown]
# ## Visualize some examples from the dataset.

# %%
# We show a few examples of training images from each class.
classes = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
]
samples_per_class = 7


def visualize_data(dataset, classes, samples_per_class):
    num_classes = len(classes)
    for y, cls in enumerate(classes):
        idxs = np.flatnonzero(y_train == y)
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
        for i, idx in enumerate(idxs):
            plt_idx = i * num_classes + y + 1
            plt.subplot(samples_per_class, num_classes, plt_idx)
            plt.imshow(dataset[idx])
            plt.axis("off")
            if i == 0:
                plt.title(cls)
    plt.show()


# Visualize the first 10 classes
visualize_data(
    x_train.reshape(5000, 3, 32, 32).transpose(0, 2, 3, 1),
    classes,
    samples_per_class,
)

# %% [markdown]
# ## Initialize the model

# %%
input_size = 3072
hidden_size = 100  # Hidden layer size (Hyper-parameter)
num_classes = 10  # Output

# For a default setting we use the same model we used for the toy dataset.
# This tells you the power of a 2 layered Neural Network. Recall the Universal Approximation Theorem.
# A 2 layer neural network with non-linearities can approximate any function, given large enough hidden layer
def init_model():
    # np.random.seed(0) # No need to fix the seed here
    l1 = Linear(input_size, hidden_size)
    l2 = Linear(hidden_size, num_classes)

    r1 = ReLU()
    softmax = Softmax()
    return Sequential([l1, r1, l2, softmax])

# %%
# Initialize the dataset with the dataloader class
dataset = DataLoader(x_train, y_train, x_val, y_val, x_test, y_test)
net = init_model()
optim = SGD(net, lr=0.01, weight_decay=0.01)
loss_func = CrossEntropyLoss()
epoch = 100  # (Hyper-parameter)
batch_size = 30  # (Reduce the batch size if your computer is unable to handle it)

# %%
# Initialize the trainer class by passing the above modules
trainer = Trainer(
    dataset, optim, net, loss_func, epoch, batch_size, validate_interval=3
)

# %%
# Call the trainer function we have already implemented for you. This trains the model for the given
# hyper-parameters. It follows the same procedure as in the last ipython notebook you used for the toy-dataset
train_error, validation_accuracy = trainer.train()
# Out:
# Epoch Average Loss: 2.301985
# Validate Acc: 0.104
# Epoch Average Loss: 2.295232
# Epoch Average Loss: 2.267212
# Epoch Average Loss: 2.221957
# Validate Acc: 0.124
# Epoch Average Loss: 2.189033
# Epoch Average Loss: 2.166634
# Epoch Average Loss: 2.152132
# Validate Acc: 0.148
# Epoch Average Loss: 2.138948
# Epoch Average Loss: 2.128496
# Epoch Average Loss: 2.119327
# Validate Acc: 0.160
# Epoch Average Loss: 2.106985
# Epoch Average Loss: 2.089667
# Epoch Average Loss: 2.070717
# Validate Acc: 0.240
# Epoch Average Loss: 2.050992
# Epoch Average Loss: 2.033781
# Epoch Average Loss: 2.019134
# Validate Acc: 0.260
# Epoch Average Loss: 2.007795
# Epoch Average Loss: 1.993574
# Epoch Average Loss: 1.980562
# Validate Acc: 0.280
# Epoch Average Loss: 1.963366
# Epoch Average Loss: 1.946348
# Epoch Average Loss: 1.933218
# Validate Acc: 0.280
# Epoch Average Loss: 1.923624
# Epoch Average Loss: 1.907331
# Epoch Average Loss: 1.896342
# Validate Acc: 0.296
# Epoch Average Loss: 1.886304
# Epoch Average Loss: 1.874319
# Epoch Average Loss: 1.862461
# Validate Acc: 0.308
# Epoch Average Loss: 1.851641
# Epoch Average Loss: 1.836221
# Epoch Average Loss: 1.824030
# Validate Acc: 0.336
# Epoch Average Loss: 1.815811
# Epoch Average Loss: 1.806651
# Epoch Average Loss: 1.796275
# Validate Acc: 0.332
# Epoch Average Loss: 1.789199
# Epoch Average Loss: 1.776692
# Epoch Average Loss: 1.765814
# Validate Acc: 0.336
# Epoch Average Loss: 1.765234
# Epoch Average Loss: 1.755100
# Epoch Average Loss: 1.749313
# Validate Acc: 0.340
# Epoch Average Loss: 1.742200
# Epoch Average Loss: 1.736783
# Epoch Average Loss: 1.729412
# Validate Acc: 0.340
# Epoch Average Loss: 1.720381
# Epoch Average Loss: 1.710655
# Epoch Average Loss: 1.705321
# Validate Acc: 0.376
# Epoch Average Loss: 1.694336
# Epoch Average Loss: 1.689542
# Epoch Average Loss: 1.691060
# Validate Acc: 0.360
# Epoch Average Loss: 1.674347
# Epoch Average Loss: 1.674147
# Epoch Average Loss: 1.672624
# Validate Acc: 0.392
# Epoch Average Loss: 1.662741
# Epoch Average Loss: 1.654879
# Epoch Average Loss: 1.652429
# Validate Acc: 0.380
# Epoch Average Loss: 1.646665
# Epoch Average Loss: 1.642824
# Epoch Average Loss: 1.638680
# Validate Acc: 0.364
# Epoch Average Loss: 1.629973
# Epoch Average Loss: 1.628234
# Epoch Average Loss: 1.623347
# Validate Acc: 0.384
# Epoch Average Loss: 1.613566
# Epoch Average Loss: 1.616687
# Epoch Average Loss: 1.604107
# Validate Acc: 0.384
# Epoch Average Loss: 1.600705
# Epoch Average Loss: 1.601555
# Epoch Average Loss: 1.595669
# Validate Acc: 0.392
# Epoch Average Loss: 1.590464
# Epoch Average Loss: 1.585420
# Epoch Average Loss: 1.582643
# Validate Acc: 0.404
# Epoch Average Loss: 1.574949
# Epoch Average Loss: 1.572964
# Epoch Average Loss: 1.567035
# Validate Acc: 0.420
# Epoch Average Loss: 1.564470
# Epoch Average Loss: 1.558179
# Epoch Average Loss: 1.547080
# Validate Acc: 0.388
# Epoch Average Loss: 1.555064
# Epoch Average Loss: 1.544931
# Epoch Average Loss: 1.534467
# Validate Acc: 0.384
# Epoch Average Loss: 1.534394
# Epoch Average Loss: 1.532948
# Epoch Average Loss: 1.532097
# Validate Acc: 0.372
# Epoch Average Loss: 1.524407
# Epoch Average Loss: 1.525058
# Epoch Average Loss: 1.515163
# Validate Acc: 0.412
# Epoch Average Loss: 1.513118
# Epoch Average Loss: 1.513591
# Epoch Average Loss: 1.503479
# Validate Acc: 0.400
# Epoch Average Loss: 1.494303
# Epoch Average Loss: 1.500477
# Epoch Average Loss: 1.497743
# Validate Acc: 0.420
# Epoch Average Loss: 1.490007
# Epoch Average Loss: 1.483750
# Epoch Average Loss: 1.477925
# Validate Acc: 0.404
# Epoch Average Loss: 1.476628
# Epoch Average Loss: 1.467210
# Epoch Average Loss: 1.465720
# Validate Acc: 0.404
# Epoch Average Loss: 1.465305
# Epoch Average Loss: 1.466206
# Epoch Average Loss: 1.458844
# Validate Acc: 0.400

# %% [markdown]
# ### Print the training and validation accuracies for the default hyper-parameters provided

# %%
from ece285.utils.evaluation import get_classification_accuracy

out_train = net.predict(x_train)
acc = get_classification_accuracy(out_train, y_train)
print("Training acc: ", acc)
out_val = net.predict(x_val)
acc = get_classification_accuracy(out_val, y_val)
print("Validation acc: ", acc)
# Out:
# Training acc:  0.4496
# Validation acc:  0.4

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy of around ~0.2 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the training loss function and the validation accuracies during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the training loss function and validation accuracies
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
# plt.plot(stats['train_acc_history'], label='train')
plt.plot(validation_accuracy, label="val")
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()

# %%
from ece285.utils.vis_utils import visualize_grid

# Credits: http://cs231n.stanford.edu/

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net._modules[0].parameters[0]
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype("uint8"))
    plt.gca().axis("off")
    plt.show()


show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters (50%)
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 40% on the validation set. Our best network gets over 40% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on cifar10 as you can (40% could serve as a reference), with a fully-connected Neural Network.

# %% [markdown]
# #### Explain your hyperparameter tuning process below.
#
# #### Your Answer:

# %%
#best_net_hyperparams = None  # store the best model into this

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model hyperparams in best_net.                                                #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# You are now free to test different combinations of hyperparameters to build   #
# various models and test them according to the above plots and visualization   #


# TODO: Show the above plots and visualizations for the default params (already #
# done) and the best hyper-params you obtain. You only need to show this for 2  #
# sets of hyper-params.                                                         #
# You just need to store values for the hyperparameters in best_net_hyperparams #
# as a list in the order
# best_net_hyperparams = [lr, weight_decay, epoch, hidden_size]
#################################################################################

#pass

# %%
# TODO: Plot the training_error and validation_accuracy of the best network (5%)

# Hyperparameter tuning
best_val_acc = 0.0
best_net = None
best_net_hyperparams = None
epoch = 20
batch_size = 10
# Define hyperparameter search space
learning_rates = [0.01, 0.05, 0.1]
hidden_sizes = [64, 128, 256]
weight_decays = [0.001, 0.01, 0.1]

for lr in learning_rates:
    for hs in hidden_sizes:
        for wd in weight_decays:
            print(f"Training with lr={lr}, hidden_size={hs}, weight_decay={wd}")
            # Initialize model
            def init_model():
                return Sequential([
                    Linear(input_size, hs),
                    ReLU(),
                    Linear(hs, num_classes),
                    Softmax()
                ])
            model = init_model()
            optimizer = SGD(model, lr=lr, weight_decay=wd)
            loss_func = CrossEntropyLoss()
            trainer = Trainer(dataset, optimizer, model, loss_func, epoch, batch_size, validate_interval=3)
            train_err, val_acc = trainer.train()
            final_val_acc = val_acc[-1] if len(val_acc) > 0 else 0
            if final_val_acc > best_val_acc:
                best_val_acc = final_val_acc
                best_net = model
                best_net_hyperparams = {"lr": lr, "hidden_size": hs, "weight_decay": wd}

print("Best validation accuracy:", best_val_acc)
print("Best hyperparameters:", best_net_hyperparams)

# TODO: visualize the weights of the best network (5%)
# Out:
# Training with lr=0.01, hidden_size=64, weight_decay=0.001
# Epoch Average Loss: 2.250507
# Validate Acc: 0.132
# Epoch Average Loss: 2.143161
# Epoch Average Loss: 2.062093
# Epoch Average Loss: 1.990689
# Validate Acc: 0.276
# Epoch Average Loss: 1.936913
# Epoch Average Loss: 1.886931
# Epoch Average Loss: 1.850585
# Validate Acc: 0.344
# Epoch Average Loss: 1.816214
# Epoch Average Loss: 1.776940
# Epoch Average Loss: 1.752885
# Validate Acc: 0.332
# Training with lr=0.01, hidden_size=64, weight_decay=0.01
# Epoch Average Loss: 2
hidden_size=256, weight_decay=0.001
# Epoch Average Loss: 2.307631
# Validate Acc: 0.084
# Epoch Average Loss: 2.306243
# Epoch Average Loss: 2.307561
# Epoch Average Loss: 2.306966
# Validate Acc: 0.120
# Epoch Average Loss: 2.306694
# Epoch Average Loss: 2.307701
# Epoch Average Loss: 2.307799
# Validate Acc: 0.096
# Epoch Average Loss: 2.307341
# Epoch Average Loss: 2.305784
# Epoch Average Loss: 2.308024
# Validate Acc: 0.084
# Training with lr=0.1, hidden_size=256, weight_decay=0.01
# Epoch Average Loss: 2.306360
# Validate Acc: 0.112
# Epoch Average Loss: 2.307249
# Epoch Average Loss: 2.306620
# Epoch Average Loss: 2.305616
# Validate Acc: 0.112
# Epoch Average Loss: 2.306855
# Epoch Average Loss: 2.306050
# Epoch Average Loss: 2.306364
# Validate Acc: 0.084
# Epoch Average Loss: 2.306540
# Epoch Average Loss: 2.305544
# Epoch Average Loss: 2.307711
# Validate Acc: 0.096
# Training with lr=0.1, hidden_size=256, weight_decay=0.1
# Epoch Average Loss: 2.306244
# Validate Acc: 0.092
# Epoch Average Loss: 2.305114
# Epoch Average Loss: 2.304770
# Epoch Average Loss: 2.305476
# Validate Acc: 0.096
# Epoch Average Loss: 2.305434
# Epoch Average Loss: 2.305568
# Epoch Average Loss: 2.305051
# Validate Acc: 0.092
# Epoch Average Loss: 2.304047
# Epoch Average Loss: 2.306095
# Epoch Average Loss: 2.304868
# Validate Acc: 0.084
# Best validation accuracy: 0.356
# Best hyperparameters: {'lr': 0.01, 'hidden_size': 64, 'weight_decay': 0.01}

# %%
# Evaluate best model
out_train = best_net.predict(x_train)
train_acc = get_classification_accuracy(out_train, y_train)
out_val = best_net.predict(x_val)
val_acc = get_classification_accuracy(out_val, y_val)
out_test = best_net.predict(x_test)
test_acc = get_classification_accuracy(out_test, y_test)

print("Best model - Training Accuracy:", train_acc)
print("Best model - Validation Accuracy:", val_acc)
print("Best model - Test Accuracy:", test_acc)

# Plot training loss and validation accuracy (re-train to collect these)
trainer = Trainer(dataset, SGD(best_net, lr=best_net_hyperparams['lr'], weight_decay=best_net_hyperparams['weight_decay']),
                  best_net, CrossEntropyLoss(), epoch, batch_size, validate_interval=3)
train_error, validation_accuracy = trainer.train()

plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History (Best Model)")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
plt.plot(validation_accuracy, label="val")
plt.title("Classification Accuracy History (Best Model)")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.show()

# Visualize weights
show_net_weights(best_net)
# Out:
# Best model - Training Accuracy: 0.3908
# Best model - Validation Accuracy: 0.356
# Best model - Test Accuracy: 0.324
# Epoch Average Loss: 1.765040
# Validate Acc: 0.372
# Epoch Average Loss: 1.742092
# Epoch Average Loss: 1.726291
# Epoch Average Loss: 1.712224
# Validate Acc: 0.332
# Epoch Average Loss: 1.701771
# Epoch Average Loss: 1.691569
# Epoch Average Loss: 1.675589
# Validate Acc: 0.368
# Epoch Average Loss: 1.657155
# Epoch Average Loss: 1.659518
# Epoch Average Loss: 1.645678
# Validate Acc: 0.348

# %% [markdown]
# # Run on the test set (30%)
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 35%.

# %%
test_acc = (best_net.predict(x_test) == y_test).mean()
print("Test accuracy: ", test_acc)
# Out:
# Test accuracy:  0.3

# %% [markdown]
# #### Inline Question (10%)
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# #### Your Answer: 1, 3
#
# #### Your Explanation: To decrease the gap between training and testing accuracy, we can train on a larger dataset and increase the regularization strength. A larger dataset provides more diverse examples, helping the model generalize better rather than memorizing training data. Increasing regularization strength (such as L2 weight decay) penalizes overly complex models, reducing the risk of overfitting. On the other hand, simply adding more hidden units increases model capacity, which can actually worsen overfitting if not properly regularized. Therefore, options 1 and 3 are effective strategies to narrow the train-test performance gap.
