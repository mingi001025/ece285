# %% [markdown]
# # ECE 285 Assignment 1: Classification using Neural Network
#
# Now that you have developed and tested your model on the toy dataset set. It's time to get down and get dirty with a standard dataset such as cifar10. At this point, you will be using the provided training data to tune the hyper-parameters of your network such that it works with cifar10 for the task of multi-class classification.
#
# Important: Recall that now we have non-linear decision boundaries, thus we do not need to do one vs all classification. We learn a single non-linear decision boundary instead. Our non-linear boundaries (thanks to relu non-linearity) will take care of differentiating between all the classes
#
# TO SUBMIT: PDF of this notebook with all the required outputs and answers.

# %%
# Prepare Packages
import numpy as np
import matplotlib.pyplot as plt

from ece285.utils.data_processing import get_cifar10_data
from ece285.utils.evaluation import get_classification_accuracy


# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # set default size of plots

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Use a subset of CIFAR10 for the assignment
dataset = get_cifar10_data(
    subset_train=5000,
    subset_val=250,
    subset_test=500,
)

print(dataset.keys())
print("Training Set Data  Shape: ", dataset["x_train"].shape)
print("Training Set Label Shape: ", dataset["y_train"].shape)
print("Validation Set Data  Shape: ", dataset["x_val"].shape)
print("Validation Set Label Shape: ", dataset["y_val"].shape)
print("Test Set Data  Shape: ", dataset["x_test"].shape)
print("Test Set Label Shape: ", dataset["y_test"].shape)
# Out:
# dict_keys(['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test'])
# Training Set Data  Shape:  (5000, 3072)
# Training Set Label Shape:  (5000,)
# Validation Set Data  Shape:  (250, 3072)
# Validation Set Label Shape:  (250,)
# Test Set Data  Shape:  (500, 3072)
# Test Set Label Shape:  (500,)

# %%
x_train = dataset["x_train"]
y_train = dataset["y_train"]
x_val = dataset["x_val"]
y_val = dataset["y_val"]
x_test = dataset["x_test"]
y_test = dataset["y_test"]

# %%
# Import more utilies and the layers you have implemented
from ece285.layers.sequential import Sequential
from ece285.layers.linear import Linear
from ece285.layers.relu import ReLU
from ece285.layers.softmax import Softmax
from ece285.layers.loss_func import CrossEntropyLoss
from ece285.utils.optimizer import SGD
from ece285.utils.dataset import DataLoader
from ece285.utils.trainer import Trainer

# %% [markdown]
# ## Visualize some examples from the dataset.

# %%
# We show a few examples of training images from each class.
classes = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
]
samples_per_class = 7


def visualize_data(dataset, classes, samples_per_class):
    num_classes = len(classes)
    for y, cls in enumerate(classes):
        idxs = np.flatnonzero(y_train == y)
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
        for i, idx in enumerate(idxs):
            plt_idx = i * num_classes + y + 1
            plt.subplot(samples_per_class, num_classes, plt_idx)
            plt.imshow(dataset[idx])
            plt.axis("off")
            if i == 0:
                plt.title(cls)
    plt.show()


# Visualize the first 10 classes
visualize_data(
    x_train.reshape(5000, 3, 32, 32).transpose(0, 2, 3, 1),
    classes,
    samples_per_class,
)

# %% [markdown]
# ## Initialize the model

# %%
input_size = 3072
hidden_size = 100  # Hidden layer size (Hyper-parameter)
num_classes = 10  # Output

# For a default setting we use the same model we used for the toy dataset.
# This tells you the power of a 2 layered Neural Network. Recall the Universal Approximation Theorem.
# A 2 layer neural network with non-linearities can approximate any function, given large enough hidden layer
def init_model():
    # np.random.seed(0) # No need to fix the seed here
    l1 = Linear(input_size, hidden_size)
    l2 = Linear(hidden_size, num_classes)

    r1 = ReLU()
    softmax = Softmax()
    return Sequential([l1, r1, l2, softmax])

# %%
# Initialize the dataset with the dataloader class
dataset = DataLoader(x_train, y_train, x_val, y_val, x_test, y_test)
net = init_model()
optim = SGD(net, lr=0.01, weight_decay=0.01)
loss_func = CrossEntropyLoss()
epoch = 100  # (Hyper-parameter)
batch_size = 30  # (Reduce the batch size if your computer is unable to handle it)

# %%
# Initialize the trainer class by passing the above modules
trainer = Trainer(
    dataset, optim, net, loss_func, epoch, batch_size, validate_interval=3
)

# %%
# Call the trainer function we have already implemented for you. This trains the model for the given
# hyper-parameters. It follows the same procedure as in the last ipython notebook you used for the toy-dataset
train_error, validation_accuracy = trainer.train()
# Out:
# Epoch Average Loss: 2.301985
# Validate Acc: 0.104
# Epoch Average Loss: 2.295232
# Epoch Average Loss: 2.267212
# Epoch Average Loss: 2.221957
# Validate Acc: 0.124
# Epoch Average Loss: 2.189033
# Epoch Average Loss: 2.166634
# Epoch Average Loss: 2.152132
# Validate Acc: 0.148
# Epoch Average Loss: 2.138948
# Epoch Average Loss: 2.128496
# Epoch Average Loss: 2.119327
# Validate Acc: 0.160
# Epoch Average Loss: 2.106985
# Epoch Average Loss: 2.089667
# Epoch Average Loss: 2.070717
# Validate Acc: 0.240
# Epoch Average Loss: 2.050992
# Epoch Average Loss: 2.033781
# Epoch Average Loss: 2.019134
# Validate Acc: 0.260
# Epoch Average Loss: 2.007795
# Epoch Average Loss: 1.993574
# Epoch Average Loss: 1.980562
# Validate Acc: 0.280
# Epoch Average Loss: 1.963366
# Epoch Average Loss: 1.946348
# Epoch Average Loss: 1.933218
# Validate Acc: 0.280
# Epoch Average Loss: 1.923624
# Epoch Average Loss: 1.907331
# Epoch Average Loss: 1.896342
# Validate Acc: 0.296
# Epoch Average Loss: 1.886304
# Epoch Average Loss: 1.874319
# Epoch Average Loss: 1.862461
# Validate Acc: 0.308
# Epoch Average Loss: 1.851641
# Epoch Average Loss: 1.836221
# Epoch Average Loss: 1.824030
# Validate Acc: 0.336
# Epoch Average Loss: 1.815811
# Epoch Average Loss: 1.806651
# Epoch Average Loss: 1.796275
# Validate Acc: 0.332
# Epoch Average Loss: 1.789199
# Epoch Average Loss: 1.776692
# Epoch Average Loss: 1.765814
# Validate Acc: 0.336
# Epoch Average Loss: 1.765234
# Epoch Average Loss: 1.755100
# Epoch Average Loss: 1.749313
# Validate Acc: 0.340
# Epoch Average Loss: 1.742200
# Epoch Average Loss: 1.736783
# Epoch Average Loss: 1.729412
# Validate Acc: 0.340
# Epoch Average Loss: 1.720381
# Epoch Average Loss: 1.710655
# Epoch Average Loss: 1.705321
# Validate Acc: 0.376
# Epoch Average Loss: 1.694336
# Epoch Average Loss: 1.689542
# Epoch Average Loss: 1.691060
# Validate Acc: 0.360
# Epoch Average Loss: 1.674347
# Epoch Average Loss: 1.674147
# Epoch Average Loss: 1.672624
# Validate Acc: 0.392
# Epoch Average Loss: 1.662741
# Epoch Average Loss: 1.654879
# Epoch Average Loss: 1.652429
# Validate Acc: 0.380
# Epoch Average Loss: 1.646665
# Epoch Average Loss: 1.642824
# Epoch Average Loss: 1.638680
# Validate Acc: 0.364
# Epoch Average Loss: 1.629973
# Epoch Average Loss: 1.628234
# Epoch Average Loss: 1.623347
# Validate Acc: 0.384
# Epoch Average Loss: 1.613566
# Epoch Average Loss: 1.616687
# Epoch Average Loss: 1.604107
# Validate Acc: 0.384
# Epoch Average Loss: 1.600705
# Epoch Average Loss: 1.601555
# Epoch Average Loss: 1.595669
# Validate Acc: 0.392
# Epoch Average Loss: 1.590464
# Epoch Average Loss: 1.585420
# Epoch Average Loss: 1.582643
# Validate Acc: 0.404
# Epoch Average Loss: 1.574949
# Epoch Average Loss: 1.572964
# Epoch Average Loss: 1.567035
# Validate Acc: 0.420
# Epoch Average Loss: 1.564470
# Epoch Average Loss: 1.558179
# Epoch Average Loss: 1.547080
# Validate Acc: 0.388
# Epoch Average Loss: 1.555064
# Epoch Average Loss: 1.544931
# Epoch Average Loss: 1.534467
# Validate Acc: 0.384
# Epoch Average Loss: 1.534394
# Epoch Average Loss: 1.532948
# Epoch Average Loss: 1.532097
# Validate Acc: 0.372
# Epoch Average Loss: 1.524407
# Epoch Average Loss: 1.525058
# Epoch Average Loss: 1.515163
# Validate Acc: 0.412
# Epoch Average Loss: 1.513118
# Epoch Average Loss: 1.513591
# Epoch Average Loss: 1.503479
# Validate Acc: 0.400
# Epoch Average Loss: 1.494303
# Epoch Average Loss: 1.500477
# Epoch Average Loss: 1.497743
# Validate Acc: 0.420
# Epoch Average Loss: 1.490007
# Epoch Average Loss: 1.483750
# Epoch Average Loss: 1.477925
# Validate Acc: 0.404
# Epoch Average Loss: 1.476628
# Epoch Average Loss: 1.467210
# Epoch Average Loss: 1.465720
# Validate Acc: 0.404
# Epoch Average Loss: 1.465305
# Epoch Average Loss: 1.466206
# Epoch Average Loss: 1.458844
# Validate Acc: 0.400

# %% [markdown]
# ### Print the training and validation accuracies for the default hyper-parameters provided

# %%
from ece285.utils.evaluation import get_classification_accuracy

out_train = net.predict(x_train)
acc = get_classification_accuracy(out_train, y_train)
print("Training acc: ", acc)
out_val = net.predict(x_val)
acc = get_classification_accuracy(out_val, y_val)
print("Validation acc: ", acc)
# Out:
# Training acc:  0.4496
# Validation acc:  0.4

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy of around ~0.2 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the training loss function and the validation accuracies during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the training loss function and validation accuracies
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
# plt.plot(stats['train_acc_history'], label='train')
plt.plot(validation_accuracy, label="val")
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()

# %%
from ece285.utils.vis_utils import visualize_grid

# Credits: http://cs231n.stanford.edu/

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net._modules[0].parameters[0]
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype("uint8"))
    plt.gca().axis("off")
    plt.show()


show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters (50%)
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 40% on the validation set. Our best network gets over 40% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on cifar10 as you can (40% could serve as a reference), with a fully-connected Neural Network.

# %% [markdown]
# #### Explain your hyperparameter tuning process below.
#
# #### Your Answer:

# %%
#best_net_hyperparams = None  # store the best model into this

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model hyperparams in best_net.                                                #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# You are now free to test different combinations of hyperparameters to build   #
# various models and test them according to the above plots and visualization   #


# TODO: Show the above plots and visualizations for the default params (already #
# done) and the best hyper-params you obtain. You only need to show this for 2  #
# sets of hyper-params.                                                         #
# You just need to store values for the hyperparameters in best_net_hyperparams #
# as a list in the order
# best_net_hyperparams = [lr, weight_decay, epoch, hidden_size]
#################################################################################

#pass

# %%
# TODO: Plot the training_error and validation_accuracy of the best network (5%)

# Hyperparameter tuning
best_val_acc = 0.0
best_net = None
best_net_hyperparams = None
epoch = 20
batch_size = 10
# Define hyperparameter search space
learning_rates = [0.01, 0.05, 0.1]
hidden_sizes = [64, 128, 256]
weight_decays = [0.001, 0.01, 0.1]

for lr in learning_rates:
    for hs in hidden_sizes:
        for wd in weight_decays:
            print(f"Training with lr={lr}, hidden_size={hs}, weight_decay={wd}")
            # Initialize model
            def init_model():
                return Sequential([
                    Linear(input_size, hs),
                    ReLU(),
                    Linear(hs, num_classes),
                    Softmax()
                ])
            model = init_model()
            optimizer = SGD(model, lr=lr, weight_decay=wd)
            loss_func = CrossEntropyLoss()
            trainer = Trainer(dataset, optimizer, model, loss_func, epoch, batch_size, validate_interval=3)
            train_err, val_acc = trainer.train()
            final_val_acc = val_acc[-1] if len(val_acc) > 0 else 0
            if final_val_acc > best_val_acc:
                best_val_acc = final_val_acc
                best_net = model
                best_net_hyperparams = {"lr": lr, "hidden_size": hs, "weight_decay": wd}

print("Best validation accuracy:", best_val_acc)
print("Best hyperparameters:", best_net_hyperparams)

# TODO: visualize the weights of the best network (5%)
# Out:
# Training with lr=0.01, hidden_size=64, weight_decay=0.001
# Epoch Average Loss: 2.290230
# Validate Acc: 0.096
# Epoch Average Loss: 2.197934
# Epoch Average Loss: 2.146722
# Epoch Average Loss: 2.111700
# Validate Acc: 0.200
# Epoch Average Loss: 2.057818
# Epoch Average Loss: 2.016006
# Epoch Average Loss: 1.987886
# Validate Acc: 0.272
# Epoch Average Loss: 1.956160
# Epoch Average Loss: 1.926265
# Epoch Average Loss: 1.895613
# Validate Acc: 0.280
# Epoch Average Loss: 1.868115
# Epoch Average Loss: 1.840358
# Epoch Average Loss: 1.808965
# Validate Acc: 0.344
# Epoch Average Loss: 1.788339
# Epoch Average Loss: 1.763152
# Epoch Average Loss: 1.742100
# Validate Acc: 0.364
# Epoch Average Loss: 1.714955
# Epoch Average Loss: 1.702826
# Epoch Average Loss: 1.678789
# Validate Acc: 0.348
# Epoch Average Loss: 1.664070
# Training with lr=0.01, hidden_size=64, weight_decay=0.01
# Epoch Average Loss: 2.290299
# Validate Acc: 0.100
# Epoch Average Loss: 2.201322
# Epoch Average Loss: 2.150245
# Epoch Average Loss: 2.121575
# Validate Acc: 0.208
# Epoch Average Loss: 2.079055
# Epoch Average Loss: 2.032996
# Epoch Average Loss: 1.998645
# Validate Acc: 0.296
# Epoch Average Loss: 1.968225
# Epoch Average Loss: 1.935822
# Epoch Average Loss: 1.906275
# Validate Acc: 0.320
# Epoch Average Loss: 1.878102
# Epoch Average Loss: 1.850113
# Epoch Average Loss: 1.825284
# Validate Acc: 0.336
# Epoch Average Loss: 1.805634
# Epoch Average Loss: 1.783057
# Epoch Average Loss: 1.767034
# Validate Acc: 0.364
# Epoch Average Loss: 1.749155
# Epoch Average Loss: 1.734384
# Epoch Average Loss: 1.723067
# Validate Acc: 0.352
# Epoch Average Loss: 1.707769
# Training with lr=0.01, hidden_size=64, weight_decay=0.1
# Epoch Average Loss: 2.295912
# Validate Acc: 0.096
# Epoch Average Loss: 2.225296
# Epoch Average Loss: 2.180901
# Epoch Average Loss: 2.166056
# Validate Acc: 0.148
# Epoch Average Loss: 2.154750
# Epoch Average Loss: 2.135374
# Epoch Average Loss: 2.111644
# Validate Acc: 0.196
# Epoch Average Loss: 2.069165
# Epoch Average Loss: 2.038233
# Epoch Average Loss: 2.022231
# Validate Acc: 0.244
# Epoch Average Loss: 2.011795
# Epoch Average Loss: 2.005899
# Epoch Average Loss: 1.991095
# Validate Acc: 0.260
# Epoch Average Loss: 1.985760
# Epoch Average Loss: 1.978973
# Epoch Average Loss: 1.974608
# Validate Acc: 0.296
# Epoch Average Loss: 1.969386
# Epoch Average Loss: 1.968956
# Epoch Average Loss: 1.966296
# Validate Acc: 0.328
# Epoch Average Loss: 1.954565
# Training with lr=0.01, hidden_size=128, weight_decay=0.001
# Epoch Average Loss: 2.289938
# Validate Acc: 0.100
# Epoch Average Loss: 2.198429
# Epoch Average Loss: 2.146791
# Epoch Average Loss: 2.111347
# Validate Acc: 0.200
# Epoch Average Loss: 2.060351
# Epoch Average Loss: 2.018219
# Epoch Average Loss: 1.984334
# Validate Acc: 0.284
# Epoch Average Loss: 1.940671
# Epoch Average Loss: 1.906733
# Epoch Average Loss: 1.877394
# Validate Acc: 0.304
# Epoch Average Loss: 1.844865
# Epoch Average Loss: 1.812144
# Epoch Average Loss: 1.787548
# Validate Acc: 0.356
# Epoch Average Loss: 1.768099
# Epoch Average Loss: 1.738716
# Epoch Average Loss: 1.720450
# Validate Acc: 0.360
# Epoch Average Loss: 1.703373
# Epoch Average Loss: 1.680207
# Epoch Average Loss: 1.667984
# Validate Acc: 0.388
# Epoch Average Loss: 1.653611
# Training with lr=0.01, hidden_size=128, weight_decay=0.01
# Epoch Average Loss: 2.287605
# Validate Acc: 0.104
# Epoch Average Loss: 2.195651
# Epoch Average Loss: 2.146762
# Epoch Average Loss: 2.112667
# Validate Acc: 0.220
# Epoch Average Loss: 2.066923
# Epoch Average Loss: 2.018364
# Epoch Average Loss: 1.977726
# Validate Acc: 0.280
# Epoch Average Loss: 1.945468
# Epoch Average Loss: 1.913642
# Epoch Average Loss: 1.888220
# Validate Acc: 0.236
# Epoch Average Loss: 1.855542
# Epoch Average Loss: 1.828742
# Epoch Average Loss: 1.807361
# Validate Acc: 0.312
# Epoch Average Loss: 1.777992
# Epoch Average Loss: 1.765951
# Epoch Average Loss: 1.744924
# Validate Acc: 0.328
# Epoch Average Loss: 1.728802
# Epoch Average Loss: 1.719331
# Epoch Average Loss: 1.703549
# Validate Acc: 0.372
# Epoch Average Loss: 1.695794
# Training with lr=0.01, hidden_size=128, weight_decay=0.1
# Epoch Average Loss: 2.289350
# Validate Acc: 0.116
# Epoch Average Loss: 2.211844
# Epoch Average Loss: 2.177208
# Epoch Average Loss: 2.162580
# Validate Acc: 0.144
# Epoch Average Loss: 2.153951
# Epoch Average Loss: 2.134004
# Epoch Average Loss: 2.111771
# Validate Acc: 0.228
# Epoch Average Loss: 2.095391
# Epoch Average Loss: 2.084774
# Epoch Average Loss: 2.053367
# Validate Acc: 0.232
# Epoch Average Loss: 2.024427
# Epoch Average Loss: 2.010319
# Epoch Average Loss: 1.994123
# Validate Acc: 0.284
# Epoch Average Loss: 1.993368
# Epoch Average Loss: 1.979795
# Epoch Average Loss: 1.977961
# Validate Acc: 0.272
# Epoch Average Loss: 1.972006
# Epoch Average Loss: 1.964243
# Epoch Average Loss: 1.963476
# Validate Acc: 0.272
# Epoch Average Loss: 1.963073
# Training with lr=0.01, hidden_size=256, weight_decay=0.001
# Epoch Average Loss: 2.282066
# Validate Acc: 0.108
# Epoch Average Loss: 2.188414
# Epoch Average Loss: 2.141740
# Epoch Average Loss: 2.102529
# Validate Acc: 0.204
# Epoch Average Loss: 2.050730
# Epoch Average Loss: 2.005216
# Epoch Average Loss: 1.966674
# Validate Acc: 0.248
# Epoch Average Loss: 1.931497
# Epoch Average Loss: 1.897517
# Epoch Average Loss: 1.860996
# Validate Acc: 0.292
# Epoch Average Loss: 1.828771
# Epoch Average Loss: 1.805608
# Epoch Average Loss: 1.778677
# Validate Acc: 0.352
# Epoch Average Loss: 1.749031
# Epoch Average Loss: 1.727414
# Epoch Average Loss: 1.704490
# Validate Acc: 0.408
# Epoch Average Loss: 1.684977
# Epoch Average Loss: 1.659489
# Epoch Average Loss: 1.648305
# Validate Acc: 0.360
# Epoch Average Loss: 1.624995
# Training with lr=0.01, hidden_size=256, weight_decay=0.01
# Epoch Average Loss: 2.285747
# Validate Acc: 0.116
# Epoch Average Loss: 2.194849
# Epoch Average Loss: 2.145584
# Epoch Average Loss: 2.110491
# Validate Acc: 0.196
# Epoch Average Loss: 2.059027
# Epoch Average Loss: 2.019067
# Epoch Average Loss: 1.975020
# Validate Acc: 0.296
# Epoch Average Loss: 1.940170
# Epoch Average Loss: 1.905473
# Epoch Average Loss: 1.878913
# Validate Acc: 0.292
# Epoch Average Loss: 1.846844
# Epoch Average Loss: 1.824756
# Epoch Average Loss: 1.804615
# Validate Acc: 0.340
# Epoch Average Loss: 1.782972
# Epoch Average Loss: 1.766596
# Epoch Average Loss: 1.744767
# Validate Acc: 0.368
# Epoch Average Loss: 1.726367
# Epoch Average Loss: 1.713882
# Epoch Average Loss: 1.702081
# Validate Acc: 0.360
# Epoch Average Loss: 1.683701
# Training with lr=0.01, hidden_size=256, weight_decay=0.1
# Epoch Average Loss: 2.287746
# Validate Acc: 0.136
# Epoch Average Loss: 2.212151
# Epoch Average Loss: 2.176486
# Epoch Average Loss: 2.163933
# Validate Acc: 0.144
# Epoch Average Loss: 2.153865
# Epoch Average Loss: 2.138520
# Epoch Average Loss: 2.109564
# Validate Acc: 0.228
# Epoch Average Loss: 2.060402
# Epoch Average Loss: 2.028890
# Epoch Average Loss: 2.021074
# Validate Acc: 0.280
# Epoch Average Loss: 2.008180
# Epoch Average Loss: 1.996781
# Epoch Average Loss: 1.988381
# Validate Acc: 0.276
# Epoch Average Loss: 1.980598
# Epoch Average Loss: 1.973822
# Epoch Average Loss: 1.969534
# Validate Acc: 0.316
# Epoch Average Loss: 1.957977
# Epoch Average Loss: 1.961268
# Epoch Average Loss: 1.960066
# Validate Acc: 0.308
# Epoch Average Loss: 1.953270
# Training with lr=0.05, hidden_size=64, weight_decay=0.001
# Epoch Average Loss: 2.216719
# Validate Acc: 0.204
# Epoch Average Loss: 2.094829
# Epoch Average Loss: 2.037988
# Epoch Average Loss: 2.001432
# Validate Acc: 0.272
# Epoch Average Loss: 1.960819
# Epoch Average Loss: 1.952779
# Epoch Average Loss: 1.908917
# Validate Acc: 0.352
# Epoch Average Loss: 1.908059
# Epoch Average Loss: 1.880210
# Epoch Average Loss: 1.869063
# Validate Acc: 0.316
# Epoch Average Loss: 1.838774
# Epoch Average Loss: 1.827302
# Epoch Average Loss: 1.818415
# Validate Acc: 0.316
# Epoch Average Loss: 1.812767
# Epoch Average Loss: 1.801840
# Epoch Average Loss: 1.792176
# Validate Acc: 0.272
# Epoch Average Loss: 1.762162
# Epoch Average Loss: 1.772345
# Epoch Average Loss: 1.756331
# Validate Acc: 0.352
# Epoch Average Loss: 1.746995
# Training with lr=0.05, hidden_size=64, weight_decay=0.01
# Epoch Average Loss: 2.212671
# Validate Acc: 0.204
# Epoch Average Loss: 2.101728
# Epoch Average Loss: 2.041977
# Epoch Average Loss: 2.007052
# Validate Acc: 0.264
# Epoch Average Loss: 1.976005
# Epoch Average Loss: 1.957971
# Epoch Average Loss: 1.937940
# Validate Acc: 0.344
# Epoch Average Loss: 1.929936
# Epoch Average Loss: 1.903032
# Epoch Average Loss: 1.917685
# Validate Acc: 0.264
# Epoch Average Loss: 1.893069
# Epoch Average Loss: 1.891644
# Epoch Average Loss: 1.883043
# Validate Acc: 0.312
# Epoch Average Loss: 1.883689
# Epoch Average Loss: 1.872006
# Epoch Average Loss: 1.865745
# Validate Acc: 0.280
# Epoch Average Loss: 1.875594
# Epoch Average Loss: 1.879905
# Epoch Average Loss: 1.871981
# Validate Acc: 0.284
# Epoch Average Loss: 1.872655
# Training with lr=0.05, hidden_size=64, weight_decay=0.1
# Epoch Average Loss: 2.238554
# Validate Acc: 0.188
# Epoch Average Loss: 2.148235
# Epoch Average Loss: 2.133235
# Epoch Average Loss: 2.122389
# Validate Acc: 0.160
# Epoch Average Loss: 2.118181
# Epoch Average Loss: 2.110500
# Epoch Average Loss: 2.117995
# Validate Acc: 0.212
# Epoch Average Loss: 2.104926
# Epoch Average Loss: 2.112678
# Epoch Average Loss: 2.110453
# Validate Acc: 0.248
# Epoch Average Loss: 2.106439
# Epoch Average Loss: 2.123479
# Epoch Average Loss: 2.111377
# Validate Acc: 0.180
# Epoch Average Loss: 2.118686
# Epoch Average Loss: 2.112725
# Epoch Average Loss: 2.105524
# Validate Acc: 0.132
# Epoch Average Loss: 2.102268
# Epoch Average Loss: 2.109469
# Epoch Average Loss: 2.107689
# Validate Acc: 0.172
# Epoch Average Loss: 2.110710
# Training with lr=0.05, hidden_size=128, weight_decay=0.001
# Epoch Average Loss: 2.205100
# Validate Acc: 0.144
# Epoch Average Loss: 2.083221
# Epoch Average Loss: 2.017937
# Epoch Average Loss: 1.980357
# Validate Acc: 0.252
# Epoch Average Loss: 1.941981
# Epoch Average Loss: 1.921058
# Epoch Average Loss: 1.910968
# Validate Acc: 0.324
# Epoch Average Loss: 1.887754
# Epoch Average Loss: 1.882985
# Epoch Average Loss: 1.853580
# Validate Acc: 0.328
# Epoch Average Loss: 1.846028
# Epoch Average Loss: 1.818540
# Epoch Average Loss: 1.807681
# Validate Acc: 0.356
# Epoch Average Loss: 1.792983
# Epoch Average Loss: 1.772391
# Epoch Average Loss: 1.782614
# Validate Acc: 0.288
# Epoch Average Loss: 1.752883
# Epoch Average Loss: 1.745848
# Epoch Average Loss: 1.722967
# Validate Acc: 0.356
# Epoch Average Loss: 1.710837
# Training with lr=0.05, hidden_size=128, weight_decay=0.01
# Epoch Average Loss: 2.202215
# Validate Acc: 0.208
# Epoch Average Loss: 2.082411
# Epoch Average Loss: 2.024559
# Epoch Average Loss: 2.002268
# Validate Acc: 0.320
# Epoch Average Loss: 1.960173
# Epoch Average Loss: 1.954062
# Epoch Average Loss: 1.939024
# Validate Acc: 0.340
# Epoch Average Loss: 1.932605
# Epoch Average Loss: 1.909440
# Epoch Average Loss: 1.902314
# Validate Acc: 0.352
# Epoch Average Loss: 1.889823
# Epoch Average Loss: 1.898791
# Epoch Average Loss: 1.891322
# Validate Acc: 0.344
# Epoch Average Loss: 1.894023
# Epoch Average Loss: 1.876401
# Epoch Average Loss: 1.869636
# Validate Acc: 0.296
# Epoch Average Loss: 1.875259
# Epoch Average Loss: 1.855543
# Epoch Average Loss: 1.866178
# Validate Acc: 0.276
# Epoch Average Loss: 1.857634
# Training with lr=0.05, hidden_size=128, weight_decay=0.1
# Epoch Average Loss: 2.248717
# Validate Acc: 0.208
# Epoch Average Loss: 2.159629
# Epoch Average Loss: 2.127033
# Epoch Average Loss: 2.131298
# Validate Acc: 0.228
# Epoch Average Loss: 2.112716
# Epoch Average Loss: 2.121219
# Epoch Average Loss: 2.121640
# Validate Acc: 0.180
# Epoch Average Loss: 2.117310
# Epoch Average Loss: 2.121417
# Epoch Average Loss: 2.117696
# Validate Acc: 0.164
# Epoch Average Loss: 2.123652
# Epoch Average Loss: 2.114023
# Epoch Average Loss: 2.116786
# Validate Acc: 0.264
# Epoch Average Loss: 2.109173
# Epoch Average Loss: 2.110976
# Epoch Average Loss: 2.111592
# Validate Acc: 0.208
# Epoch Average Loss: 2.108607
# Epoch Average Loss: 2.108091
# Epoch Average Loss: 2.119489
# Validate Acc: 0.196
# Epoch Average Loss: 2.121540
# Training with lr=0.05, hidden_size=256, weight_decay=0.001
# Epoch Average Loss: 2.219734
# Validate Acc: 0.136
# Epoch Average Loss: 2.058785
# Epoch Average Loss: 1.994096
# Epoch Average Loss: 1.928483
# Validate Acc: 0.348
# Epoch Average Loss: 1.901043
# Epoch Average Loss: 1.861241
# Epoch Average Loss: 1.828957
# Validate Acc: 0.288
# Epoch Average Loss: 1.830500
# Epoch Average Loss: 1.799936
# Epoch Average Loss: 1.778910
# Validate Acc: 0.384
# Epoch Average Loss: 1.748059
# Epoch Average Loss: 1.733225
# Epoch Average Loss: 1.711779
# Validate Acc: 0.388
# Epoch Average Loss: 1.691896
# Epoch Average Loss: 1.681335
# Epoch Average Loss: 1.653162
# Validate Acc: 0.344
# Epoch Average Loss: 1.639292
# Epoch Average Loss: 1.624230
# Epoch Average Loss: 1.618914
# Validate Acc: 0.348
# Epoch Average Loss: 1.593231
# Training with lr=0.05, hidden_size=256, weight_decay=0.01
# Epoch Average Loss: 2.210970
# Validate Acc: 0.208
# Epoch Average Loss: 2.063707
# Epoch Average Loss: 2.001497
# Epoch Average Loss: 1.959387
# Validate Acc: 0.240
# Epoch Average Loss: 1.929611
# Epoch Average Loss: 1.910808
# Epoch Average Loss: 1.904353
# Validate Acc: 0.344
# Epoch Average Loss: 1.899534
# Epoch Average Loss: 1.876261
# Epoch Average Loss: 1.871205
# Validate Acc: 0.352
# Epoch Average Loss: 1.866345
# Epoch Average Loss: 1.855239
# Epoch Average Loss: 1.851896
# Validate Acc: 0.328
# Epoch Average Loss: 1.844409
# Epoch Average Loss: 1.856148
# Epoch Average Loss: 1.832824
# Validate Acc: 0.356
# Epoch Average Loss: 1.830868
# Epoch Average Loss: 1.841715
# Epoch Average Loss: 1.844272
# Validate Acc: 0.336
# Epoch Average Loss: 1.829895
# Training with lr=0.05, hidden_size=256, weight_decay=0.1
# Epoch Average Loss: 2.229333
# Validate Acc: 0.196
# Epoch Average Loss: 2.170779
# Epoch Average Loss: 2.136888
# Epoch Average Loss: 2.124616
# Validate Acc: 0.188
# Epoch Average Loss: 2.117906
# Epoch Average Loss: 2.101792
# Epoch Average Loss: 2.114290
# Validate Acc: 0.228
# Epoch Average Loss: 2.119307
# Epoch Average Loss: 2.112126
# Epoch Average Loss: 2.109846
# Validate Acc: 0.228
# Epoch Average Loss: 2.110896
# Epoch Average Loss: 2.111356
# Epoch Average Loss: 2.114155
# Validate Acc: 0.220
# Epoch Average Loss: 2.110642
# Epoch Average Loss: 2.114092
# Epoch Average Loss: 2.112696
# Validate Acc: 0.236
# Epoch Average Loss: 2.114079
# Epoch Average Loss: 2.114026
# Epoch Average Loss: 2.106889
# Validate Acc: 0.180
# Epoch Average Loss: 2.108867
# Training with lr=0.1, hidden_size=64, weight_decay=0.001
# Epoch Average Loss: 2.304624
# Validate Acc: 0.096
# Epoch Average Loss: 2.304425
# Epoch Average Loss: 2.304510
# Epoch Average Loss: 2.304895
# Validate Acc: 0.088
# Epoch Average Loss: 2.304446
# Epoch Average Loss: 2.304886
# Epoch Average Loss: 2.304693
# Validate Acc: 0.104
# Epoch Average Loss: 2.305280
# Epoch Average Loss: 2.305504
# Epoch Average Loss: 2.304924
# Validate Acc: 0.096
# Epoch Average Loss: 2.304847
# Epoch Average Loss: 2.304768
# Epoch Average Loss: 2.304504
# Validate Acc: 0.088
# Epoch Average Loss: 2.304892
# Epoch Average Loss: 2.304069
# Epoch Average Loss: 2.305209
# Validate Acc: 0.112
# Epoch Average Loss: 2.304844
# Epoch Average Loss: 2.304953
# Epoch Average Loss: 2.304399
# Validate Acc: 0.084
# Epoch Average Loss: 2.304978
# Training with lr=0.1, hidden_size=64, weight_decay=0.01
# Epoch Average Loss: 2.304316
# Validate Acc: 0.084
# Epoch Average Loss: 2.303811
# Epoch Average Loss: 2.294850
# Epoch Average Loss: 2.268116
# Validate Acc: 0.088
# Epoch Average Loss: 2.282228
# Epoch Average Loss: 2.266356
# Epoch Average Loss: 2.283985
# Validate Acc: 0.092
# Epoch Average Loss: 2.306208
# Epoch Average Loss: 2.304233
# Epoch Average Loss: 2.296120
# Validate Acc: 0.112
# Epoch Average Loss: 2.295718
# Epoch Average Loss: 2.303631
# Epoch Average Loss: 2.298038
# Validate Acc: 0.088
# Epoch Average Loss: 2.298316
# Epoch Average Loss: 2.305405
# Epoch Average Loss: 2.275408
# Validate Acc: 0.136
# Epoch Average Loss: 2.234509
# Epoch Average Loss: 2.283857
# Epoch Average Loss: 2.282513
# Validate Acc: 0.092
# Epoch Average Loss: 2.278392
# Training with lr=0.1, hidden_size=64, weight_decay=0.1
# Epoch Average Loss: 2.301751
# Validate Acc: 0.096
# Epoch Average Loss: 2.304489
# Epoch Average Loss: 2.303359
# Epoch Average Loss: 2.303185
# Validate Acc: 0.092
# Epoch Average Loss: 2.303695
# Epoch Average Loss: 2.304387
# Epoch Average Loss: 2.303104
# Validate Acc: 0.120
# Epoch Average Loss: 2.303751
# Epoch Average Loss: 2.303955
# Epoch Average Loss: 2.304526
# Validate Acc: 0.084
# Epoch Average Loss: 2.305019
# Epoch Average Loss: 2.304334
# Epoch Average Loss: 2.303391
# Validate Acc: 0.084
# Epoch Average Loss: 2.303242
# Epoch Average Loss: 2.302937
# Epoch Average Loss: 2.303686
# Validate Acc: 0.104
# Epoch Average Loss: 2.303806
# Epoch Average Loss: 2.303816
# Epoch Average Loss: 2.303678
# Validate Acc: 0.088
# Epoch Average Loss: 2.303959
# Training with lr=0.1, hidden_size=128, weight_decay=0.001
# Epoch Average Loss: 2.304441
# Validate Acc: 0.116
# Epoch Average Loss: 2.262064
# Epoch Average Loss: 2.292789
# Epoch Average Loss: 2.302868
# Validate Acc: 0.112
# Epoch Average Loss: 2.294893
# Epoch Average Loss: 2.245890
# Epoch Average Loss: 2.274508
# Validate Acc: 0.096
# Epoch Average Loss: 2.281052
# Epoch Average Loss: 2.248720
# Epoch Average Loss: 2.241779
# Validate Acc: 0.088
# Epoch Average Loss: 2.305778
# Epoch Average Loss: 2.304197
# Epoch Average Loss: 2.304137
# Validate Acc: 0.084
# Epoch Average Loss: 2.304557
# Epoch Average Loss: 2.304901
# Epoch Average Loss: 2.304837
# Validate Acc: 0.104
# Epoch Average Loss: 2.305032
# Epoch Average Loss: 2.305632
# Epoch Average Loss: 2.304789
# Validate Acc: 0.096
# Epoch Average Loss: 2.304628
# Training with lr=0.1, hidden_size=128, weight_decay=0.01
# Epoch Average Loss: 2.288819
# Validate Acc: 0.112
# Epoch Average Loss: 2.273084
# Epoch Average Loss: 2.268615
# Epoch Average Loss: 2.225479
# Validate Acc: 0.184
# Epoch Average Loss: 2.225485
# Epoch Average Loss: 2.262559
# Epoch Average Loss: 2.256955
# Validate Acc: 0.140
# Epoch Average Loss: 2.261498
# Epoch Average Loss: 2.249158
# Epoch Average Loss: 2.242520
# Validate Acc: 0.132
# Epoch Average Loss: 2.255455
# Epoch Average Loss: 2.249290
# Epoch Average Loss: 2.273584
# Validate Acc: 0.088
# Epoch Average Loss: 2.271034
# Epoch Average Loss: 2.241555
# Epoch Average Loss: 2.242190
# Validate Acc: 0.128
# Epoch Average Loss: 2.251516
# Epoch Average Loss: 2.255916
# Epoch Average Loss: 2.291953
# Validate Acc: 0.140
# Epoch Average Loss: 2.267578
# Training with lr=0.1, hidden_size=128, weight_decay=0.1
# Epoch Average Loss: 2.303905
# Validate Acc: 0.088
# Epoch Average Loss: 2.304018
# Epoch Average Loss: 2.289581
# Epoch Average Loss: 2.284483
# Validate Acc: 0.120
# Epoch Average Loss: 2.292331
# Epoch Average Loss: 2.303931
# Epoch Average Loss: 2.303498
# Validate Acc: 0.112
# Epoch Average Loss: 2.304803
# Epoch Average Loss: 2.303358
# Epoch Average Loss: 2.303328
# Validate Acc: 0.084
# Epoch Average Loss: 2.302993
# Epoch Average Loss: 2.303858
# Epoch Average Loss: 2.303801
# Validate Acc: 0.112
# Epoch Average Loss: 2.303506
# Epoch Average Loss: 2.302901
# Epoch Average Loss: 2.303992
# Validate Acc: 0.088
# Epoch Average Loss: 2.304341
# Epoch Average Loss: 2.303583
# Epoch Average Loss: 2.303450
# Validate Acc: 0.084
# Epoch Average Loss: 2.303729
# Training with lr=0.1, hidden_size=256, weight_decay=0.001
# Epoch Average Loss: 2.297099
# Validate Acc: 0.108
# Epoch Average Loss: 2.258309
# Epoch Average Loss: 2.272629
# Epoch Average Loss: 2.304237
# Validate Acc: 0.120
# Epoch Average Loss: 2.248142
# Epoch Average Loss: 2.269611
# Epoch Average Loss: 2.306584
# Epoch Average Loss: 2.305358
# Validate Acc: 0.088
# Epoch Average Loss: 2.304310
# Epoch Average Loss: 2.298022
# Epoch Average Loss: 2.305141
# Validate Acc: 0.096
# Epoch Average Loss: 2.304390
# Epoch Average Loss: 2.304790
# Epoch Average Loss: 2.304017
# Validate Acc: 0.120
# Epoch Average Loss: 2.305318
# Training with lr=0.1, hidden_size=256, weight_decay=0.01
# Epoch Average Loss: 2.287429
# Validate Acc: 0.100
# Epoch Average Loss: 2.263121
# Epoch Average Loss: 2.263701
# Epoch Average Loss: 2.274110
# Validate Acc: 0.124
# Epoch Average Loss: 2.255208
# Epoch Average Loss: 2.274305
# Epoch Average Loss: 2.235406
# Validate Acc: 0.144
# Epoch Average Loss: 2.257340
# Epoch Average Loss: 2.255362
# Epoch Average Loss: 2.265198
# Validate Acc: 0.128
# Epoch Average Loss: 2.264425
# Epoch Average Loss: 2.306906
# Epoch Average Loss: 2.293586
# Validate Acc: 0.084
# Epoch Average Loss: 2.284262
# Epoch Average Loss: 2.263756
# Epoch Average Loss: 2.263365
# Validate Acc: 0.100
# Epoch Average Loss: 2.242346
# Epoch Average Loss: 2.271764
# Epoch Average Loss: 2.279273
# Validate Acc: 0.120
# Epoch Average Loss: 2.220682
# Training with lr=0.1, hidden_size=256, weight_decay=0.1
# Epoch Average Loss: 2.304022
# Validate Acc: 0.112
# Epoch Average Loss: 2.303982
# Epoch Average Loss: 2.303717
# Epoch Average Loss: 2.303589
# Validate Acc: 0.112
# Epoch Average Loss: 2.303780
# Epoch Average Loss: 2.303699
# Epoch Average Loss: 2.303702
# Validate Acc: 0.096
# Epoch Average Loss: 2.304244
# Epoch Average Loss: 2.303859
# Epoch Average Loss: 2.304103
# Validate Acc: 0.092
# Epoch Average Loss: 2.304221
# Epoch Average Loss: 2.303843
# Epoch Average Loss: 2.304184
# Validate Acc: 0.084
# Epoch Average Loss: 2.303957
# Epoch Average Loss: 2.303455
# Epoch Average Loss: 2.303639
# Validate Acc: 0.096
# Epoch Average Loss: 2.303917
# Epoch Average Loss: 2.303464
# Epoch Average Loss: 2.304554
# Validate Acc: 0.088
# Epoch Average Loss: 2.303637
# Best validation accuracy: 0.388
# Best hyperparameters: {'lr': 0.01, 'hidden_size': 128, 'weight_decay': 0.001}

# %%
# Evaluate best model
out_train = best_net.predict(x_train)
train_acc = get_classification_accuracy(out_train, y_train)
out_val = best_net.predict(x_val)
val_acc = get_classification_accuracy(out_val, y_val)
out_test = best_net.predict(x_test)
test_acc = get_classification_accuracy(out_test, y_test)

print("Best model - Training Accuracy:", train_acc)
print("Best model - Validation Accuracy:", val_acc)
print("Best model - Test Accuracy:", test_acc)

# Plot training loss and validation accuracy (re-train to collect these)
trainer = Trainer(dataset, SGD(best_net, lr=best_net_hyperparams['lr'], weight_decay=best_net_hyperparams['weight_decay']),
                  best_net, CrossEntropyLoss(), epoch, batch_size, validate_interval=3)
train_error, validation_accuracy = trainer.train()

plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History (Best Model)")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
plt.plot(validation_accuracy, label="val")
plt.title("Classification Accuracy History (Best Model)")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.show()

# Visualize weights
show_net_weights(best_net)
# Out:
# Best model - Training Accuracy: 0.414
# Best model - Validation Accuracy: 0.372
# Best model - Test Accuracy: 0.326
# Epoch Average Loss: 1.629268
# Validate Acc: 0.368
# Epoch Average Loss: 1.621166
# Epoch Average Loss: 1.596118
# Epoch Average Loss: 1.576337
# Validate Acc: 0.416
# Epoch Average Loss: 1.561749
# Epoch Average Loss: 1.544566
# Epoch Average Loss: 1.530225
# Validate Acc: 0.392
# Epoch Average Loss: 1.506879
# Epoch Average Loss: 1.498317
# Epoch Average Loss: 1.479816
# Validate Acc: 0.436
# Epoch Average Loss: 1.469363
# Epoch Average Loss: 1.453626
# Epoch Average Loss: 1.439261
# Validate Acc: 0.412
# Epoch Average Loss: 1.422193
# Epoch Average Loss: 1.401317
# Epoch Average Loss: 1.388015
# Validate Acc: 0.416
# Epoch Average Loss: 1.385867
# Epoch Average Loss: 1.366980
# Epoch Average Loss: 1.351375
# Validate Acc: 0.428
# Epoch Average Loss: 1.338563

# %% [markdown]
# # Run on the test set (30%)
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 35%.

# %%
test_acc = (best_net.predict(x_test) == y_test).mean()
print("Test accuracy: ", test_acc)
# Out:
# Test accuracy:  0.368

# %% [markdown]
# #### Inline Question (10%)
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# #### Your Answer: 1, 3
#
# #### Your Explanation: To decrease the gap between training and testing accuracy, we can train on a larger dataset and increase the regularization strength. A larger dataset provides more diverse examples, helping the model generalize better rather than memorizing training data. Increasing regularization strength (such as L2 weight decay) penalizes overly complex models, reducing the risk of overfitting. On the other hand, simply adding more hidden units increases model capacity, which can actually worsen overfitting if not properly regularized. Therefore, options 1 and 3 are effective strategies to narrow the train-test performance gap.
